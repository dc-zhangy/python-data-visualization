# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# # 默认风格
# matplotlib默认风格

# %%
sinplot()

# %% [markdown]
# seaborn的默认风格

# %%
sns.set()
sinplot()

# %% [markdown]
# # Seaborn设计风格
# `seaborn`中有5种预设主题：`darkgrid`、`whitegrid`、`dark`、`white`和`ticks`。它们各自针对不同的应用和个人偏好。默认的主题是`darkgrid`。

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);

# %%
sns.set_style("dark")
sinplot()

# %%
sns.set_style("white")
sinplot()

# %% [markdown]
# 增加刻度尺

# %%
sns.set_style("ticks")
sinplot()

# %% [markdown]
# # 去除图形边线
# `sns.despine()`

# %%
sinplot()
sns.despine()

# %%
sns.set_style("whitegrid")
sns.boxplot(data=data, palette="deep")
sns.despine(left=True);

# %% [markdown]
#  调整边界与图形之间的距离

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);

# %% [markdown]
# # 临时修改设计风格

# %%
f = plt.figure()
with sns.axes_style("darkgrid"):
    ax = f.add_subplot(1, 2, 1)
    sinplot()
ax = f.add_subplot(1, 2, 2)
sinplot(-1)

# %% [markdown]
# # 重载seaborn的设计元素

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sinplot()

# %% [markdown]
# # 缩放图形元素
# `sns.set_context():paper`、`paper`、`notebook`、`talk`和`poster`
#
# 使图片可以适应不同的应用场景（有时可能需要更大的图片，但有时却刚好相反）

# %%
#重置所有的设置
sns.set()
sns.set_context("paper")
sinplot()

# %%
sns.set_context("talk")
sinplot()

# %%
sns.set_context("poster")
sinplot()

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sinplot()
